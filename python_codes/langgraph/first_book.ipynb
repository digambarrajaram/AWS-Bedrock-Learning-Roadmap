# %%
# %pip install langchain langchain-deepseek langgraph
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#   Using cached pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from os import getenv

load_dotenv()
# Out:
# True

# %%
from langchain.llms.bedrock import Bedrock #type: ignore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from langchain.llms.bedrock import Bedrock #type: ignore
#
# ModuleNotFoundError: No module named 'langchain.llms'
